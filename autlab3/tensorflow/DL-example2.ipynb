# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle

pickle_in = open('/content/drive/MyDrive/Colab/DL/X.pickle',"rb")
X = pickle.load(pickle_in)

pickle_in = open('/content/drive/MyDrive/Colab/DL/y.pickle',"rb")
y = pickle.load(pickle_in)

# %% [markdown]
# # Verificar

# %%
print("X type of variable:"+str(type(X)))
print("X shape:"+str(X.shape))
print("y type of variable:"+str(type(y)))
# Out:
# X type of variable:<class 'numpy.ndarray'>
# X shape:(24966, 100, 100, 1)
# y type of variable:<class 'list'>

# %%
import numpy as np

y = np.array(y)
print("y New type of variable:"+str(type(y)))

print("Input Y variable:"+str(X.shape[1:]))
# Out:
# y New type of variable:<class 'numpy.ndarray'>
# Input Y variable:(100, 100, 1)

# %% [markdown]
# # Normalizando

# %%
X = X/255.0

# %% [markdown]
# # CNN

# %%
model = Sequential()

model.add(Conv2D(128, (3, 3), input_shape=X.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())  # this converts our 2D feature maps to 1D feature vectors

model.add(Dense(128))

model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model.fit(X, y, batch_size=32, epochs=30, validation_split=0.3)
# Out:
# Epoch 1/30
# 547/547 [==============================] - 45s 64ms/step - loss: 0.6682 - accuracy: 0.6120 - val_loss: 0.6380 - val_accuracy: 0.6545
# Epoch 2/30
# 547/547 [==============================] - 34s 63ms/step - loss: 0.6074 - accuracy: 0.6781 - val_loss: 0.5944 - val_accuracy: 0.6911
# Epoch 3/30
# 547/547 [==============================] - 34s 63ms/step - loss: 0.5686 - accuracy: 0.7095 - val_loss: 0.5712 - val_accuracy: 0.7099
# Epoch 4/30
# 547/547 [==============================] - 34s 63ms/step - loss: 0.5324 - accuracy: 0.7355 - val_loss: 0.6086 - val_accuracy: 0.6816
# Epoch 5/30
# 547/547 [==============================] - 34s 63ms/step - loss: 0.4969 - accuracy: 0.7612 - val_loss: 0.5111 - val_accuracy: 0.7618
# Epoch 6/30
# 547/547 [==============================] - 35s 65ms/step - loss: 0.4626 - accuracy: 0.7839 - val_loss: 0.5232 - val_accuracy: 0.7575
# Epoch 7/30
# 547/547 [==============================] - 35s 64ms/step - loss: 0.4396 - accuracy: 0.7973 - val_loss: 0.5044 - val_accuracy: 0.7724
# Epoch 8/30
# 547/547 [==============================] - 34s 63ms/step - loss: 0.4235 - accuracy: 0.8048 - val_loss: 0.5015 - val_accuracy: 0.7720
# Epoch 9/30
# 547/547 [==============================] - 35s 64ms/step - loss: 0.4062 - accuracy: 0.8125 - val_loss: 0.5124 - val_accuracy: 0.7581
# Epoch 10/30
# 547/547 [==============================] - 34s 63ms/step - loss: 0.3904 - accuracy: 0.8258 - val_loss: 0.5224 - val_accuracy: 0.7668
# Epoch 11/30
# 547/547 [==============================] - 34s 63ms/step - loss: 0.3683 - accuracy: 0.8351 - val_loss: 0.5298 - val_accuracy: 0.7638
# Epoch 12/30
# 547/547 [==============================] - 35s 64ms/step - loss: 0.3472 - accuracy: 0.8468 - val_loss: 0.5503 - val_accuracy: 0.7586
# Epoch 13/30
# 547/547 [==============================] - 34s 63ms/step - loss: 0.3334 - accuracy: 0.8525 - val_loss: 0.5769 - val_accuracy: 0.7601
# Epoch 14/30
# 547/547 [==============================] - 34s 63ms/step - loss: 0.3133 - accuracy: 0.8631 - val_loss: 0.5579 - val_accuracy: 0.7676
# Epoch 15/30
# 547/547 [==============================] - 35s 64ms/step - loss: 0.2990 - accuracy: 0.8693 - val_loss: 0.6020 - val_accuracy: 0.7626
# Epoch 16/30
# 547/547 [==============================] - 34s 63ms/step - loss: 0.2828 - accuracy: 0.8777 - val_loss: 0.6641 - val_accuracy: 0.7470
# Epoch 17/30
# 547/547 [==============================] - 35s 64ms/step - loss: 0.2696 - accuracy: 0.8842 - val_loss: 0.6693 - val_accuracy: 0.7505
# Epoch 18/30
# 547/547 [==============================] - 34s 63ms/step - loss: 0.2582 - accuracy: 0.8902 - val_loss: 0.6699 - val_accuracy: 0.7485
# Epoch 19/30
# 547/547 [==============================] - 35s 64ms/step - loss: 0.2389 - accuracy: 0.8983 - val_loss: 0.7025 - val_accuracy: 0.7626
# Epoch 20/30
# 547/547 [==============================] - 34s 62ms/step - loss: 0.2268 - accuracy: 0.9025 - val_loss: 0.7331 - val_accuracy: 0.7554
# Epoch 21/30
# 547/547 [==============================] - 34s 62ms/step - loss: 0.2246 - accuracy: 0.9040 - val_loss: 0.8157 - val_accuracy: 0.7514
# Epoch 22/30
# 547/547 [==============================] - 35s 64ms/step - loss: 0.2085 - accuracy: 0.9135 - val_loss: 0.7992 - val_accuracy: 0.7585
# Epoch 23/30
# 547/547 [==============================] - 34s 63ms/step - loss: 0.1994 - accuracy: 0.9183 - val_loss: 0.8234 - val_accuracy: 0.7545
# Epoch 24/30
# 547/547 [==============================] - 34s 63ms/step - loss: 0.1853 - accuracy: 0.9233 - val_loss: 0.8907 - val_accuracy: 0.7497
# Epoch 25/30
# 547/547 [==============================] - 35s 64ms/step - loss: 0.1797 - accuracy: 0.9267 - val_loss: 1.0055 - val_accuracy: 0.7493
# Epoch 26/30
# 547/547 [==============================] - 34s 63ms/step - loss: 0.1745 - accuracy: 0.9284 - val_loss: 0.9522 - val_accuracy: 0.7438
# Epoch 27/30
# 547/547 [==============================] - 35s 65ms/step - loss: 0.1623 - accuracy: 0.9339 - val_loss: 1.0730 - val_accuracy: 0.7490
# Epoch 28/30
# 547/547 [==============================] - 34s 62ms/step - loss: 0.1565 - accuracy: 0.9357 - val_loss: 1.0868 - val_accuracy: 0.7463
# Epoch 29/30
# 547/547 [==============================] - 34s 63ms/step - loss: 0.1515 - accuracy: 0.9390 - val_loss: 1.0674 - val_accuracy: 0.7407
# Epoch 30/30
# 547/547 [==============================] - 35s 65ms/step - loss: 0.1397 - accuracy: 0.9428 - val_loss: 1.1626 - val_accuracy: 0.7381
